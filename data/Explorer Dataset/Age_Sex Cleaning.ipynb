# %%
from IPython.display import display
import pandas as pd
import numpy as np
from pathlib import Path

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 150)

# %%
INPUT_FILE = Path(
    r"C:\Users\bhara\OneDrive\Desktop\DAMO-699-Capstone-Project-Unofficial-\DAMO-699-Capstone-Project-Unofficial-\data\optimized\Age_Sex.csv"
)

# %%
OUTPUT_FOLDER = Path(
    r"C:\Users\bhara\OneDrive\Desktop\DAMO-699-Capstone-Project-Unofficial-\DAMO-699-Capstone-Project-Unofficial-\data\Explorer Dataset"
)

# %%
OUTPUT_FOLDER.mkdir(parents=True, exist_ok=True)

OUTPUT_FILE = OUTPUT_FOLDER / "Age_Sex.csv"

# %%
df = pd.read_csv(INPUT_FILE)

# %%
print("DATASET LOADED SUCCESSFULLY")
# Out:
# DATASET LOADED SUCCESSFULLY

# %%
print("\nFIRST 10 ROWS\n")
print(df.head(10))

print("\nLAST 10 ROWS\n")
print(df.tail(10))
# Out:
# FIRST 10 ROWS
#
#   fiscal_year  sex age_group  ed_visits  median_length_of_stay_min  fiscal_year_start  length_of_stay_hours age_broad_category
# 0   2021-2022  All     00–04    1038994                      162.0               2021                   2.7              Adult
# 1   2021-2022  All     05–09     431471                      150.0               2021                   2.5              Adult
# 2   2021-2022  All     10–14     460661                      162.0               2021                   2.7              Adult
# 3   2021-2022  All     15–19     709180                      186.0               2021                   3.1              Adult
# 4   2021-2022  All     20–24     914580                      192.0               2021                   3.2              Adult
# 5   2021-2022  All     25–29     991719                      192.0               2021                   3.2              Adult
# 6   2021-2022  All     30–34     985223                      198.0               2021                   3.3              Adult
# 7   2021-2022  All     35–39     913671                      204.0               2021                   3.4              Adult
# 8   2021-2022  All     40–44     823576                      210.0               2021                   3.5              Adult
# 9   2021-2022  All     45–49     767559                      216.0               2021                   3.6              Adult
#
# LAST 10 ROWS
#
#      fiscal_year   sex age_group  ed_visits  median_length_of_stay_min  fiscal_year_start  length_of_stay_hours age_broad_category
# 1073   2003-2004  Male     45–49     157174                      127.0               2003                  2.12              Adult
# 1074   2003-2004  Male     50–54     133258                      134.0               2003                  2.23              Adult
# 1075   2003-2004  Male     55–59     119849                      138.0               2003                  2.30              Adult
# 1076   2003-2004  Male     60–64      98075                      149.0               2003                  2.48              Adult
# 1077   2003-2004  Male     65–69      93477                      160.0               2003                  2.67             Senior
# 1078   2003-2004  Male     70–74      96390                      175.0               2003                  2.92              Adult
# 1079   2003-2004  Male     75–79      90448                      190.0               2003                  3.17             Senior
# 1080   2003-2004  Male     80–84      67706                      211.0               2003                  3.52              Adult
# 1081   2003-2004  Male       85+      48770                      235.0               2003                  3.92             Senior
# 1082   2003-2004  Male     Total    2430701                      122.0               2003                  2.03              Adult

# %%
print("\nDATASET SHAPE")
print(df.shape)

print("\nCOLUMN NAMES")
print(df.columns.tolist())

print("\nDATA TYPES")
print(df.dtypes)

print("\nMISSING VALUES")
print(df.isnull().sum())

print("\nDUPLICATE ROWS")
print(df.duplicated().sum())

print("\nUNIQUE SEX VALUES")
print(df["sex"].unique())

print("\nUNIQUE AGE GROUPS")
print(df["age_group"].unique())
# Out:
# DATASET SHAPE
# (1083, 8)
#
# COLUMN NAMES
# ['fiscal_year', 'sex', 'age_group', 'ed_visits', 'median_length_of_stay_min', 'fiscal_year_start', 'length_of_stay_hours', 'age_broad_category']
#
# DATA TYPES
# fiscal_year                      str
# sex                              str
# age_group                        str
# ed_visits                      int64
# median_length_of_stay_min    float64
# fiscal_year_start              int64
# length_of_stay_hours         float64
# age_broad_category               str
# dtype: object
#
# MISSING VALUES
# fiscal_year                  0
# sex                          0
# age_group                    0
# ed_visits                    0
# median_length_of_stay_min    0
# fiscal_year_start            0
# length_of_stay_hours         0
# age_broad_category           0
# dtype: int64
#
# DUPLICATE ROWS
# 0
#
# UNIQUE SEX VALUES
# <ArrowStringArray>
# ['All', 'Female', 'Male']
# Length: 3, dtype: str
#
# UNIQUE AGE GROUPS
# <ArrowStringArray>
# ['00–04', '05–09', '10–14', '15–19', '20–24', '25–29', '30–34', '35–39', '40–44', '45–49', '50–54', '55–59', '60–64', '65–69', '70–74', '75–79',
#  '80–84',   '85+', 'Total']
# Length: 19, dtype: str

# %%
print("\nSUMMARY STATISTICS")
print(df.describe(include="all"))
# Out:
# SUMMARY STATISTICS
#        fiscal_year   sex age_group     ed_visits  median_length_of_stay_min  fiscal_year_start  length_of_stay_hours age_broad_category
# count         1083  1083      1083  1.083000e+03                1083.000000        1083.000000           1083.000000               1083
# unique          19     3        19           NaN                        NaN                NaN                   NaN                  2
# top      2021-2022   All     00–04           NaN                        NaN                NaN                   NaN              Adult
# freq            57   361        57           NaN                        NaN                NaN                   NaN                912
# mean           NaN   NaN       NaN  6.492164e+05                 174.935826        2012.000000              2.915605                NaN
# std            NaN   NaN       NaN  1.511598e+06                  56.132491           5.479756              0.935553                NaN
# min            NaN   NaN       NaN  4.877000e+04                  92.000000        2003.000000              1.530000                NaN
# 25%            NaN   NaN       NaN  1.934985e+05                 137.000000        2007.000000              2.280000                NaN
# 50%            NaN   NaN       NaN  3.147110e+05                 160.000000        2012.000000              2.670000                NaN
# 75%            NaN   NaN       NaN  4.536285e+05                 198.000000        2017.000000              3.300000                NaN
# max            NaN   NaN       NaN  1.508440e+07                 426.000000        2021.000000              7.100000                NaN

# %%
print("\nRemoving rows where Sex = 'All'...")

df = df[df["sex"].str.lower() != "all"].copy()
# Out:
# Removing rows where Sex = 'All'...

# %%
df.rename(
    columns={
        "median_length_of_stay_min": "median_los_minutes",
        "length_of_stay_hours": "median_los_hours"
    },
    inplace=True
)

# %%
df["median_los_minutes"] = (
    pd.to_numeric(df["median_los_minutes"], errors="coerce")
    .round()
    .astype("Int64")
)

# %%
def population_category(age):

    age = str(age).strip()

    pediatric = [
        "0-4", "5-9", "10-14", "15-19",
        "00-04", "05-09", "10-14", "15-19"
    ]

    young_adult = [
        "20-24", "25-29", "30-34"
    ]

    adult = [
        "35-39", "40-44", "45-49"
    ]

    pre_senior = [
        "50-54", "55-59", "60-64"
    ]

    geriatric = [
        "65-69", "70-74", "75-79", "80-84", "85+"
    ]

    if age in pediatric:
        return "0–17: Pediatric Population"

    elif age in young_adult:
        return "18–34: Young Adult Population"

    elif age in adult:
        return "35–49: Adult Population"

    elif age in pre_senior:
        return "50–64: Pre-Senior Population"

    elif age in geriatric:
        return "65–85+: Geriatric Population"

    else:
        return "Unknown"


df["population_category"] = df["age_group"].apply(population_category)

# %%
if "age_broad_category" in df.columns:
    df.drop(columns=["age_broad_category"], inplace=True)

# %%
df = df[
    [
        "fiscal_year",
        "fiscal_year_start",
        "sex",
        "age_group",
        "population_category",
        "ed_visits",
        "median_los_minutes",
        "median_los_hours",
    ]
]

# %%
df = df.sort_values(
    by=[
        "fiscal_year_start",
        "age_group",
        "sex"
    ]
).reset_index(drop=True)

# %%
print("\nFINAL SHAPE")
print(df.shape)
# Out:
# FINAL SHAPE
# (722, 8)

# %%
print("\nFINAL MISSING VALUES")
print(df.isnull().sum())
# Out:
# FINAL MISSING VALUES
# fiscal_year            0
# fiscal_year_start      0
# sex                    0
# age_group              0
# population_category    0
# ed_visits              0
# median_los_minutes     0
# median_los_hours       0
# dtype: int64

# %%
print("\nFINAL DUPLICATES")
print(df.duplicated().sum())
# Out:
# FINAL DUPLICATES
# 0

# %%
print("\nFINAL COLUMN NAMES")
print(df.columns.tolist())
# Out:
# FINAL COLUMN NAMES
# ['fiscal_year', 'fiscal_year_start', 'sex', 'age_group', 'population_category', 'ed_visits', 'median_los_minutes', 'median_los_hours']

# %%
print("\nPOPULATION CATEGORY COUNTS")
print(df["population_category"].value_counts())
# Out:
# POPULATION CATEGORY COUNTS
# population_category
# Unknown                         684
# 65–85+: Geriatric Population     38
# Name: count, dtype: int64

# %%
print("\nFINAL DATASET (TOP 20 ROWS)")
print(df.head(20))
# Out:
# FINAL DATASET (TOP 20 ROWS)
#    fiscal_year  fiscal_year_start     sex age_group population_category  ed_visits  median_los_minutes  median_los_hours
# 0    2003-2004               2003  Female     00–04             Unknown     209397                 100              1.67
# 1    2003-2004               2003    Male     00–04             Unknown     259969                 101              1.68
# 2    2003-2004               2003  Female     05–09             Unknown     109174                  92              1.53
# 3    2003-2004               2003    Male     05–09             Unknown     132665                  95              1.58
# 4    2003-2004               2003  Female     10–14             Unknown     113853                  99              1.65
# 5    2003-2004               2003    Male     10–14             Unknown     141235                 100              1.67
# 6    2003-2004               2003  Female     15–19             Unknown     178730                 110              1.83
# 7    2003-2004               2003    Male     15–19             Unknown     168363                 105              1.75
# 8    2003-2004               2003  Female     20–24             Unknown     187147                 122              2.03
# 9    2003-2004               2003    Male     20–24             Unknown     169427                 111              1.85
# 10   2003-2004               2003  Female     25–29             Unknown     173660                 128              2.13
# 11   2003-2004               2003    Male     25–29             Unknown     148113                 115              1.92
# 12   2003-2004               2003  Female     30–34             Unknown     171961                 130              2.17
# 13   2003-2004               2003    Male     30–34             Unknown     153633                 116              1.93
# 14   2003-2004               2003  Female     35–39             Unknown     173196                 129              2.15
# 15   2003-2004               2003    Male     35–39             Unknown     171189                 120              2.00
# 16   2003-2004               2003  Female     40–44             Unknown     176470                 127              2.12
# 17   2003-2004               2003    Male     40–44             Unknown     180960                 123              2.05
# 18   2003-2004               2003  Female     45–49             Unknown     153812                 131              2.18
# 19   2003-2004               2003    Male     45–49             Unknown     157174                 127              2.12

# %%
print("\nFINAL DATASET (BOTTOM 20 ROWS)")
print(df.tail(20))
# Out:
# FINAL DATASET (BOTTOM 20 ROWS)
#     fiscal_year  fiscal_year_start     sex age_group           population_category  ed_visits  median_los_minutes  median_los_hours
# 702   2021-2022               2021  Female     45–49                       Unknown     393414                 222               3.7
# 703   2021-2022               2021    Male     45–49                       Unknown     373948                 210               3.5
# 704   2021-2022               2021  Female     50–54                       Unknown     399024                 222               3.7
# 705   2021-2022               2021    Male     50–54                       Unknown     394742                 216               3.6
# 706   2021-2022               2021  Female     55–59                       Unknown     436243                 222               3.7
# 707   2021-2022               2021    Male     55–59                       Unknown     453515                 228               3.8
# 708   2021-2022               2021  Female     60–64                       Unknown     424869                 234               3.9
# 709   2021-2022               2021    Male     60–64                       Unknown     451222                 240               4.0
# 710   2021-2022               2021  Female     65–69                       Unknown     383888                 258               4.3
# 711   2021-2022               2021    Male     65–69                       Unknown     400315                 258               4.3
# 712   2021-2022               2021  Female     70–74                       Unknown     371212                 282               4.7
# 713   2021-2022               2021    Male     70–74                       Unknown     371766                 276               4.6
# 714   2021-2022               2021  Female     75–79                       Unknown     330714                 312               5.2
# 715   2021-2022               2021    Male     75–79                       Unknown     313747                 300               5.0
# 716   2021-2022               2021  Female     80–84                       Unknown     281685                 348               5.8
# 717   2021-2022               2021    Male     80–84                       Unknown     242891                 336               5.6
# 718   2021-2022               2021  Female       85+  65–85+: Geriatric Population     416579                 426               7.1
# 719   2021-2022               2021    Male       85+  65–85+: Geriatric Population     286361                 396               6.6
# 720   2021-2022               2021  Female     Total                       Unknown    7230587                 222               3.7
# 721   2021-2022               2021    Male     Total                       Unknown    6763252                 210               3.5

# %%
# Normalize age group formatting
df["age_group"] = (
    df["age_group"]
    .astype(str)
    .str.strip()
    .str.replace("–", "-", regex=False)
    .str.replace("—", "-", regex=False)
)

# %%
age_mapping = {
    "00-04": "0–17",
    "0-4": "0–17",
    "05-09": "0–17",
    "5-9": "0–17",
    "10-14": "0–17",
    "15-19": "0–17",

    "20-24": "18–34",
    "25-29": "18–34",
    "30-34": "18–34",

    "35-39": "35–49",
    "40-44": "35–49",
    "45-49": "35–49",

    "50-54": "50–64",
    "55-59": "50–64",
    "60-64": "50–64",

    "65-69": "65–85+",
    "70-74": "65–85+",
    "75-79": "65–85+",
    "80-84": "65–85+",
    "85+": "65–85+"
}

# %%
df["age_group"] = df["age_group"].map(age_mapping)

# %%
population_mapping = {
    "0–17": "Pediatric Population",
    "18–34": "Young Adult Population",
    "35–49": "Adult Population",
    "50–64": "Pre-Senior Population",
    "65–85+": "Geriatric Population"
}

df["population_category"] = df["age_group"].map(population_mapping)

# %%
print("\nFINAL DATASET (TOP 20 ROWS)")
print(df.head(20))
# Out:
# FINAL DATASET (TOP 20 ROWS)
#    fiscal_year  fiscal_year_start     sex age_group     population_category  ed_visits  median_los_minutes  median_los_hours
# 0    2003-2004               2003  Female      0–17    Pediatric Population     209397                 100              1.67
# 1    2003-2004               2003    Male      0–17    Pediatric Population     259969                 101              1.68
# 2    2003-2004               2003  Female      0–17    Pediatric Population     109174                  92              1.53
# 3    2003-2004               2003    Male      0–17    Pediatric Population     132665                  95              1.58
# 4    2003-2004               2003  Female      0–17    Pediatric Population     113853                  99              1.65
# 5    2003-2004               2003    Male      0–17    Pediatric Population     141235                 100              1.67
# 6    2003-2004               2003  Female      0–17    Pediatric Population     178730                 110              1.83
# 7    2003-2004               2003    Male      0–17    Pediatric Population     168363                 105              1.75
# 8    2003-2004               2003  Female     18–34  Young Adult Population     187147                 122              2.03
# 9    2003-2004               2003    Male     18–34  Young Adult Population     169427                 111              1.85
# 10   2003-2004               2003  Female     18–34  Young Adult Population     173660                 128              2.13
# 11   2003-2004               2003    Male     18–34  Young Adult Population     148113                 115              1.92
# 12   2003-2004               2003  Female     18–34  Young Adult Population     171961                 130              2.17
# 13   2003-2004               2003    Male     18–34  Young Adult Population     153633                 116              1.93
# 14   2003-2004               2003  Female     35–49        Adult Population     173196                 129              2.15
# 15   2003-2004               2003    Male     35–49        Adult Population     171189                 120              2.00
# 16   2003-2004               2003  Female     35–49        Adult Population     176470                 127              2.12
# 17   2003-2004               2003    Male     35–49        Adult Population     180960                 123              2.05
# 18   2003-2004               2003  Female     35–49        Adult Population     153812                 131              2.18
# 19   2003-2004               2003    Male     35–49        Adult Population     157174                 127              2.12

# %%
print("\nFINAL DATASET (BOTTOM 20 ROWS)")
print(df.tail(20))
# Out:
# FINAL DATASET (BOTTOM 20 ROWS)
#     fiscal_year  fiscal_year_start     sex age_group    population_category  ed_visits  median_los_minutes  median_los_hours
# 702   2021-2022               2021  Female     35–49       Adult Population     393414                 222               3.7
# 703   2021-2022               2021    Male     35–49       Adult Population     373948                 210               3.5
# 704   2021-2022               2021  Female     50–64  Pre-Senior Population     399024                 222               3.7
# 705   2021-2022               2021    Male     50–64  Pre-Senior Population     394742                 216               3.6
# 706   2021-2022               2021  Female     50–64  Pre-Senior Population     436243                 222               3.7
# 707   2021-2022               2021    Male     50–64  Pre-Senior Population     453515                 228               3.8
# 708   2021-2022               2021  Female     50–64  Pre-Senior Population     424869                 234               3.9
# 709   2021-2022               2021    Male     50–64  Pre-Senior Population     451222                 240               4.0
# 710   2021-2022               2021  Female    65–85+   Geriatric Population     383888                 258               4.3
# 711   2021-2022               2021    Male    65–85+   Geriatric Population     400315                 258               4.3
# 712   2021-2022               2021  Female    65–85+   Geriatric Population     371212                 282               4.7
# 713   2021-2022               2021    Male    65–85+   Geriatric Population     371766                 276               4.6
# 714   2021-2022               2021  Female    65–85+   Geriatric Population     330714                 312               5.2
# 715   2021-2022               2021    Male    65–85+   Geriatric Population     313747                 300               5.0
# 716   2021-2022               2021  Female    65–85+   Geriatric Population     281685                 348               5.8
# 717   2021-2022               2021    Male    65–85+   Geriatric Population     242891                 336               5.6
# 718   2021-2022               2021  Female    65–85+   Geriatric Population     416579                 426               7.1
# 719   2021-2022               2021    Male    65–85+   Geriatric Population     286361                 396               6.6
# 720   2021-2022               2021  Female       NaN                    NaN    7230587                 222               3.7
# 721   2021-2022               2021    Male       NaN                    NaN    6763252                 210               3.5

# %%
df.head
# Out:
# <bound method NDFrame.head of     fiscal_year  fiscal_year_start     sex age_group   population_category  ed_visits  median_los_minutes  median_los_hours
# 0     2003-2004               2003  Female      0–17  Pediatric Population     209397                 100              1.67
# 1     2003-2004               2003    Male      0–17  Pediatric Population     259969                 101              1.68
# 2     2003-2004               2003  Female      0–17  Pediatric Population     109174                  92              1.53
# 3     2003-2004               2003    Male      0–17  Pediatric Population     132665                  95              1.58
# 4     2003-2004               2003  Female      0–17  Pediatric Population     113853                  99              1.65
# ..          ...                ...     ...       ...                   ...        ...                 ...               ...
# 717   2021-2022               2021    Male    65–85+  Geriatric Population     242891                 336              5.60
# 718   2021-2022               2021  Female    65–85+  Geriatric Population     416579                 426              7.10
# 719   2021-2022               2021    Male    65–85+  Geriatric Population     286361                 396              6.60
# 720   2021-2022               2021  Female       NaN                   NaN    7230587                 222              3.70
# 721   2021-2022               2021    Male       NaN                   NaN    6763252                 210              3.50
#
# [722 rows x 8 columns]>

# %%
# Weighted average function
def weighted_average(group):
    return round(
        np.average(
            group["median_los_minutes"],
            weights=group["ed_visits"]
        )
    )

df = (
    df.groupby(
        [
            "fiscal_year",
            "fiscal_year_start",
            "sex",
            "age_group",
            "population_category"
        ],
        as_index=False
    )
    .apply(
        lambda g: pd.Series({
            "ed_visits": g["ed_visits"].sum(),
            "median_los_minutes": weighted_average(g)
        })
    )
    .reset_index(drop=True)
)

# %%
df["median_los_hours"] = (
    df["median_los_minutes"] / 60
).round(2)

# %%
df = df[
    [
        "fiscal_year",
        "fiscal_year_start",
        "sex",
        "age_group",
        "population_category",
        "ed_visits",
        "median_los_minutes",
        "median_los_hours"
    ]
]

# %%
age_order = {
    "0-17": 1,
    "18-34": 2,
    "35-49": 3,
    "50-64": 4,
    "65-85+": 5
}

df["age_sort"] = df["age_group"].map(age_order)

df = (
    df.sort_values(
        ["fiscal_year_start", "age_sort", "sex"]
    )
    .drop(columns="age_sort")
    .reset_index(drop=True)
)

# %%
display(df)
# Out:
#     fiscal_year  fiscal_year_start     sex age_group     population_category  ed_visits  median_los_minutes  median_los_hours
# 0     2003-2004               2003  Female      0–17    Pediatric Population     611154                 101              1.68
# 1     2003-2004               2003  Female     18–34  Young Adult Population     532768                 127              2.12
# 2     2003-2004               2003  Female     35–49        Adult Population     503478                 129              2.15
# 3     2003-2004               2003  Female     50–64   Pre-Senior Population     349504                 141              2.35
# 4     2003-2004               2003  Female    65–85+    Geriatric Population     478789                 203              3.38
# ..          ...                ...     ...       ...                     ...        ...                 ...               ...
# 185   2021-2022               2021    Male      0–17    Pediatric Population    1345417                 160              2.67
# 186   2021-2022               2021    Male     18–34  Young Adult Population    1299236                 186              3.10
# 187   2021-2022               2021    Male     35–49        Adult Population    1202684                 204              3.40
# 188   2021-2022               2021    Male     50–64   Pre-Senior Population    1299479                 229              3.82
# 189   2021-2022               2021    Male    65–85+    Geriatric Population    1615080                 307              5.12
#
# [190 rows x 8 columns]

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %%
print(f"Rows    : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")

print("\nColumn Names")
print(df.columns.tolist())

print("\nMissing Values")
print(df.isnull().sum())

print("\nDuplicate Rows")
print(df.duplicated().sum())

print("\nUnique Age Groups")
print(df["age_group"].unique())

print("\nPopulation Categories")
print(df["population_category"].unique())

print("\nSex")
print(df["sex"].unique())
# Out:
# Rows    : 190
# Columns : 8
#
# Column Names
# ['fiscal_year', 'fiscal_year_start', 'sex', 'age_group', 'population_category', 'ed_visits', 'median_los_minutes', 'median_los_hours']
#
# Missing Values
# fiscal_year            0
# fiscal_year_start      0
# sex                    0
# age_group              0
# population_category    0
# ed_visits              0
# median_los_minutes     0
# median_los_hours       0
# dtype: int64
#
# Duplicate Rows
# 0
#
# Unique Age Groups
# <ArrowStringArray>
# ['0–17', '18–34', '35–49', '50–64', '65–85+']
# Length: 5, dtype: str
#
# Population Categories
# <ArrowStringArray>
# [  'Pediatric Population', 'Young Adult Population',       'Adult Population',
#   'Pre-Senior Population',   'Geriatric Population']
# Length: 5, dtype: str
#
# Sex
# <ArrowStringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
preview_file = OUTPUT_FOLDER / "Age_Sex_Preview.xlsx"
df.to_excel(preview_file, index=False)
